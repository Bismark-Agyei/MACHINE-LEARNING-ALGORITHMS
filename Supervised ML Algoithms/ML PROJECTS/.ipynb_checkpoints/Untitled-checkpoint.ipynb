# %%
import pandas as pd
fed_files = ["MORTGAGE3OUS.csv", "RRVRUSQ156N.csv", " CPIAUCSL.csv"]
dfs = [pd.read_csv(f, parse_dates=Tru, index_col=0) for f in fed_files]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 fed_files = ["MORTGAGE3OUS.csv", "RRVRUSQ156N.csv", " CPIAUCSL.csv"]
#       3 dfs = [pd.read_csv(f, parse_dates=Tru, index_col=0) for f in fed_files]
#
# ModuleNotFoundError: No module named 'pandas'
